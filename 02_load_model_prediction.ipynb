# %%
pip install tensorflow keras matplotlib pydot pydotplus graphviz pyyaml h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import matplotlib.pyplot as plt

# %%
model = tf.keras.models.load_model("turtle_v_pengin_model.keras")

# %%
image_size = (512, 512)

img = keras.utils.load_img(
    "./tux.png", target_size=image_size
)

# %%
plt.imshow(img)

# %%
img_array = keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
predictions = model.predict(img_array)
predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# array([[0.56963784]], dtype=float32)

# %%
score = float(predictions[0])
score
# Out:
# /tmp/ipykernel_7262/2314994182.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(predictions[0])
# 0.5696378350257874

# %%
print(f"This image is {100 * (1 - score):.2f}% penguim and {100 * score:.2f}% turtle.")
# Out:
# This image is 43.04% penguim and 56.96% turtle.

# %%
image_size = (512, 512)

img2 = keras.utils.load_img(
    "./tux_tiny.png", target_size=image_size
)

# %%
plt.imshow(img2)

# %%
img_array2 = keras.utils.img_to_array(img2)
img_array2 = tf.expand_dims(img_array2, 0)

# %%
predictions2 = model.predict(img_array2)
predictions2
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# array([[0.58740056]], dtype=float32)

# %%
score2 = float(predictions2[0])
score2
# Out:
# /tmp/ipykernel_7262/4143397865.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score2 = float(predictions2[0])
# 0.5874005556106567

# %%
print(f"This image is {100 * (1 - score2):.2f}% penguim and {100 * score2:.2f}% turtle.")
# Out:
# This image is 41.26% penguim and 58.74% turtle.
